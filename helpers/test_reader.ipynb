# %%
from torchvision.io import read_image
import os
import pandas as pd
sys.path.insert(0, '../')
from helpers import model_pipeline, helpers, data_loader

CONFIG = helpers.get_config()

# %%
TRAIN_SET = pd.read_csv(CONFIG['DATA_DIR_TRAINSET'])
TEST_SET = CONFIG['DATA_DIR_TESTSET']
RAW_DATA = CONFIG['DATA_DIR_RESIZED']

# %%
img_dir = RAW_DATA
img_labels = TRAIN_SET

# %%
idx = 0

img_path = os.path.join(img_dir, img_labels.iloc[idx, 0])
image = read_image(img_path)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [20], in <cell line: 4>()
#       1 idx = 0
#       3 img_path = os.path.join(img_dir, img_labels.iloc[idx, 0])
# ----> 4 image = read_image(img_path)
#
# File D:\Programs\anaconda\lib\site-packages\torchvision\io\image.py:246, in read_image(path, mode)
#     244     _log_api_usage_once(read_image)
#     245 data = read_file(path)
# --> 246 return decode_image(data, mode)
#
# File D:\Programs\anaconda\lib\site-packages\torchvision\io\image.py:223, in decode_image(input, mode)
#     221 if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#     222     _log_api_usage_once(decode_image)
# --> 223 output = torch.ops.image.decode_image(input, mode.value)
#     224 return output
#
# File D:\Programs\anaconda\lib\site-packages\torch\_ops.py:143, in OpOverloadPacket.__call__(self, *args, **kwargs)
# ...

# %%
from PIL import Image

# %%
Image.open(img_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>
